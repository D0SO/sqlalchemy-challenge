# %%
from flask import Flask, jsonify, render_template

import datetime as dt

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

import numpy as np
import json
import pandas as pd

# Create egine for database connection
sql = "sqlite:///Resources/hawaii.sqlite"
engine = create_engine(sql, pool_pre_ping=True)

# Create autmap_base 
Base = automap_base()
# Reflect database tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

session = Session(engine)

# Setup Flask

app = Flask(__name__)

# Create initital route with route's summary
@app.route("/")
def welcome():
    return (
        f"Welcome to the Hawaii Weather API!<br/>"
        f"Available Routes:<br/>"
        f"/api/v1.0/precipitation<br/>"
        f"/api/v1.0/stations<br/>"
        f"/api/v1.0/tobs<br/>"
        f"/api/v1.0/start_date<br/>"
        f"/api/v1.0/start_date/end_date<br/>"
        f"Please enter date as yyyy-mm-dd")
    
# Create an app route to returning date and percipitation data in JSON format

@app.route("/api/v1.0/precipitation")
def preci():
    """Return Percipitation Data - 1 year"""
    # Create a variable to filter only the last year of analysis
    last_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)
    # Query for the date and precipitation for the last year
    rainfall = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= last_year).all()
    # Transform our query into a list
    rain = list(np.ravel(rainfall))
    # Return the data in json format
    return jsonify(rain=rain)

@app.route("/api/v1.0/stations")
def stations():
    """List of stations."""
    # Query the name of each station in our DB
    stat = session.query(Station.station).all()
    # Transform our query into a list
    station_list = list(np.ravel(stat))
    # Return the data in json format
    return jsonify(station_list=station_list)

@app.route("/api/v1.0/tobs")
def tobs():
    # Create a variable to filter only the last year of analysis
    last_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)
    
    temp = session.query(Measurement.date, Measurement.tobs).filter(Measurement.station == 'USC00519281').filter(Measurement.date >= last_year).all()
    
    tobs_list = list(np.ravel(temp))
    
    return jsonify(tobs_list=tobs_list)

@app.route("/api/v1.0/<start_date>")
def st(start=None):
    
    start_temp = session.query(func.min(Measurement.tobs),func.avg(Measurement.tobs),func.max(Measurement.tobs)).filter(Measurement.date >= start).all()

    start_list = list(np.ravel(start_temp))
    
    return jsonify(start_list=start_list)

@app.route("/api/v1.0/<start_date>/<end_date>")
def st_end(start=None ,end=None):
    
    min_max = session.query(func.min(Measurement.tobs),func.avg(Measurement.tobs),func.max(Measurement.tobs)).filter(Measurement.date >= start, Measurement.date <= end).all()

    min_max_list = list(np.ravel(min_max))
    
    return jsonify(min_max_list=min_max_list)


if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [04/Mar/2021 21:40:57] "GET / HTTP/1.1" 200 -
# [2021-03-04 21:41:03,861] ERROR in app: Exception on /api/v1.0/start_date [GET]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
# TypeError: st() got an unexpected keyword argument 'start_date'
# 127.0.0.1 - - [04/Mar/2021 21:41:03] "GET /api/v1.0/start_date HTTP/1.1" 500 -
# 127.0.0.1 - - [04/Mar/2021 21:41:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Mar/2021 21:41:25] "GET /api/v1.0/precipitation HTTP/1.1" 200 -
# [2021-03-04 21:41:31,659] ERROR in app: Exception on /api/v1.0/tobs [GET]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1204, in _execute_context
#     context = constructor(dialect, self, conn, *args)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\default.py", line 806, in _init_compiled
#     self.cursor = self.create_cursor()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\default.py", line 1162, in create_cursor
#     return self._dbapi_connection.cursor()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\pool\base.py", line 1000, in cursor
#     return self.connection.cursor(*args, **kwargs)
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 22848 and this is thread id 18504.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-11b7569b600c>", line 75, in tobs
#     temp = session.query(Measurement.date, Measurement.tobs).filter(Measurement.station == 'USC00519281').filter(Measurement.date >= last_year).all()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\orm\query.py", line 3373, in all
#     return list(self)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\orm\query.py", line 3535, in __iter__
#     return self._execute_and_instances(context)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\orm\query.py", line 3560, in _execute_and_instances
#     result = conn.execute(querycontext.statement, self._params)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1011, in execute
#     return meth(self, multiparams, params)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\sql\elements.py", line 298, in _execute_on_connection
#     return connection._execute_clauseelement(self, multiparams, params)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1130, in _execute_clauseelement
#     distilled_params,
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1207, in _execute_context
#     e, util.text_type(statement), parameters, None, None
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1511, in _handle_dbapi_exception
#     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\util\compat.py", line 182, in raise_
#     raise exception
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1204, in _execute_context
#     context = constructor(dialect, self, conn, *args)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\default.py", line 806, in _init_compiled
#     self.cursor = self.create_cursor()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\default.py", line 1162, in create_cursor
#     return self._dbapi_connection.cursor()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\pool\base.py", line 1000, in cursor
#     return self.connection.cursor(*args, **kwargs)
# sqlalchemy.exc.ProgrammingError: (sqlite3.ProgrammingError) SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 22848 and this is thread id 18504.
# [SQL: SELECT measurement.date AS measurement_date, measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE measurement.station = ? AND measurement.date >= ?]
# [parameters: [immutabledict({})]]
# (Background on this error at: http://sqlalche.me/e/13/f405)
# 127.0.0.1 - - [04/Mar/2021 21:41:31] "GET /api/v1.0/tobs HTTP/1.1" 500 -
# [2021-03-04 21:41:35,022] ERROR in app: Exception on /api/v1.0/tobs [GET]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1204, in _execute_context
#     context = constructor(dialect, self, conn, *args)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\default.py", line 806, in _init_compiled
#     self.cursor = self.create_cursor()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\default.py", line 1162, in create_cursor
#     return self._dbapi_connection.cursor()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\pool\base.py", line 1000, in cursor
#     return self.connection.cursor(*args, **kwargs)
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 22848 and this is thread id 13948.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-11b7569b600c>", line 75, in tobs
#     temp = session.query(Measurement.date, Measurement.tobs).filter(Measurement.station == 'USC00519281').filter(Measurement.date >= last_year).all()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\orm\query.py", line 3373, in all
#     return list(self)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\orm\query.py", line 3535, in __iter__
#     return self._execute_and_instances(context)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\orm\query.py", line 3560, in _execute_and_instances
#     result = conn.execute(querycontext.statement, self._params)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1011, in execute
#     return meth(self, multiparams, params)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\sql\elements.py", line 298, in _execute_on_connection
#     return connection._execute_clauseelement(self, multiparams, params)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1130, in _execute_clauseelement
#     distilled_params,
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1207, in _execute_context
#     e, util.text_type(statement), parameters, None, None
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1511, in _handle_dbapi_exception
#     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\util\compat.py", line 182, in raise_
#     raise exception
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\base.py", line 1204, in _execute_context
#     context = constructor(dialect, self, conn, *args)
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\default.py", line 806, in _init_compiled
#     self.cursor = self.create_cursor()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\engine\default.py", line 1162, in create_cursor
#     return self._dbapi_connection.cursor()
#   File "C:\ProgramData\Anaconda3\envs\class_31\lib\site-packages\sqlalchemy\pool\base.py", line 1000, in cursor
#     return self.connection.cursor(*args, **kwargs)
# sqlalchemy.exc.ProgrammingError: (sqlite3.ProgrammingError) SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 22848 and this is thread id 13948.
# [SQL: SELECT measurement.date AS measurement_date, measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE measurement.station = ? AND measurement.date >= ?]
# [parameters: [immutabledict({})]]
# (Background on this error at: http://sqlalche.me/e/13/f405)
# 127.0.0.1 - - [04/Mar/2021 21:41:35] "GET /api/v1.0/tobs HTTP/1.1" 500 -
